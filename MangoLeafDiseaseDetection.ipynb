# %%
# Decision Tree

import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Define the directories and parameters
data_dir = '/content/drive/MyDrive/mango'
img_size = (240, 320)

# Load the data
labels = labels = list(set(os.listdir(os.path.join(data_dir, 'train'))))

X_train, y_train = [], []
X_val, y_val = [], []
X_test, y_test = [], []
for label in labels:
    for img_name in os.listdir(os.path.join(data_dir, 'train', label)):
        img_path = os.path.join(data_dir, 'train', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_train.append(img_to_array(img))
        y_train.append(label)
    for img_name in os.listdir(os.path.join(data_dir, 'val', label)):
        img_path = os.path.join(data_dir, 'val', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_val.append(img_to_array(img))
        y_val.append(label)
    for img_name in os.listdir(os.path.join(data_dir, 'test', label)):
        img_path = os.path.join(data_dir, 'test', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_test.append(img_to_array(img))
        y_test.append(label)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
import os

data_dir = '/content/drive/MyDrive/mango/train'
labels = [dir for dir in os.listdir(data_dir) if dir != '.DS_Store']

for label in labels:
    label_dir = os.path.join(data_dir, label)
    img_names = os.listdir(label_dir)[:2]
    for img_name in img_names:
        img_path = os.path.join(label_dir, img_name)
        print(f'Label: {label}, Image: {img_name}')
        img = cv2.imread(img_path)
        cv2_imshow(img)

# %%
# Decision Tree

import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Define the directories and parameters
data_dir = '/content/drive/MyDrive/mango'
img_size = (240, 320)

# Load the data
labels = os.listdir(os.path.join(data_dir, 'train'))
X_train, y_train = [], []
X_val, y_val = [], []
X_test, y_test = [], []
for label in labels:
    for img_name in os.listdir(os.path.join(data_dir, 'train', label)):
        img_path = os.path.join(data_dir, 'train', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_train.append(img_to_array(img))
        y_train.append(label)
    for img_name in os.listdir(os.path.join(data_dir, 'val', label)):
        img_path = os.path.join(data_dir, 'val', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_val.append(img_to_array(img))
        y_val.append(label)
    for img_name in os.listdir(os.path.join(data_dir, 'test', label)):
        img_path = os.path.join(data_dir, 'test', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_test.append(img_to_array(img))
        y_test.append(label)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)
X_test = np.array(X_test)
y_test = np.array(y_test)

# Preprocess the data
X_train = X_train.reshape(X_train.shape[0], -1) / 255.0
X_val = X_val.reshape(X_val.shape[0], -1) / 255.0
X_test = X_test.reshape(X_test.shape[0], -1) / 255.0

# Encode the labels
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

# Train a decision tree classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# Evaluate the classifier on the validation set
y_val_pred = clf.predict(X_val)
val_acc = accuracy_score(y_val, y_val_pred)
print(f'Validation accuracy: {val_acc:.3f}')

# Evaluate the classifier on the test set
y_test_pred = clf.predict(X_test)
test_acc = accuracy_score(y_test, y_test_pred)
print(f'Test accuracy: {test_acc:.3f}')

# %%
# import required libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# instantiate decision tree classifier with tuned hyperparameters
dtc = DecisionTreeClassifier(max_depth=5)

# fit the model on the training data
dtc.fit(X_train, y_train)

# predict on the test data
y_pred = dtc.predict(X_test)

# print classification report to evaluate the performance of the model
print(classification_report(y_test, y_pred))

# %%
# Random Forest
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Define the directories and parameters
data_dir = '/content/drive/MyDrive/mango'
img_size = (240, 320)

# Load the data
labels = os.listdir(os.path.join(data_dir, 'train'))
X_train, y_train = [], []
X_val, y_val = [], []
X_test, y_test = [], []
for label in labels:
    for img_name in os.listdir(os.path.join(data_dir, 'train', label)):
        img_path = os.path.join(data_dir, 'train', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_train.append(img_to_array(img))
        y_train.append(label)
    for img_name in os.listdir(os.path.join(data_dir, 'val', label)):
        img_path = os.path.join(data_dir, 'val', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_val.append(img_to_array(img))
        y_val.append(label)
    for img_name in os.listdir(os.path.join(data_dir, 'test', label)):
        img_path = os.path.join(data_dir, 'test', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_test.append(img_to_array(img))
        y_test.append(label)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)
X_test = np.array(X_test)
y_test = np.array(y_test)

# Preprocess the data
X_train = X_train.reshape(X_train.shape[0], -1) / 255.0
X_val = X_val.reshape(X_val.shape[0], -1) / 255.0
X_test = X_test.reshape(X_test.shape[0], -1) / 255.0

# Encode the labels
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

# Train a random forest classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Evaluate the classifier on the validation set
y_val_pred = clf.predict(X_val)
val_acc = accuracy_score(y_val, y_val_pred)
print(f'Validation accuracy: {val_acc:.3f}')

# Evaluate the classifier on the test set
y_test_pred = clf.predict(X_test)
test_acc = accuracy_score(y_test, y_test_pred)
print(f'Test accuracy: {test_acc:.3f}')

# %%
# SVM

import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Define the directories and parameters
data_dir = '/content/drive/MyDrive/mango'
img_size = (240, 320)

# Load the data
labels = os.listdir(os.path.join(data_dir, 'train'))
X_train, y_train = [], []
X_val, y_val = [], []
X_test, y_test = [], []
for label in labels:
    for img_name in os.listdir(os.path.join(data_dir, 'train', label)):
        img_path = os.path.join(data_dir, 'train', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_train.append(img_to_array(img))
        y_train.append(label)
    for img_name in os.listdir(os.path.join(data_dir, 'val', label)):
        img_path = os.path.join(data_dir, 'val', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_val.append(img_to_array(img))
        y_val.append(label)
    for img_name in os.listdir(os.path.join(data_dir, 'test', label)):
        img_path = os.path.join(data_dir, 'test', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_test.append(img_to_array(img))
        y_test.append(label)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)
X_test = np.array(X_test)
y_test = np.array(y_test)

# Preprocess the data
X_train = X_train.reshape(X_train.shape[0], -1) / 255.0
X_val = X_val.reshape(X_val.shape[0], -1) / 255.0
X_test = X_test.reshape(X_test.shape[0], -1) / 255.0

# Encode the labels
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

# Train a decision tree classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# Evaluate the classifier on the validation set
y_val_pred = clf.predict(X_val)
val_acc = accuracy_score(y_val, y_val_pred)
print(f'Validation accuracy: {val_acc:.3f}')

# Evaluate the classifier on the test set
y_test_pred = clf.predict(X_test)
test_acc = accuracy_score(y_test, y_test_pred)
print(f'Test accuracy: {test_acc:.3f}')

# %%
#KNN

import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Define the directories and parameters
data_dir = '/content/drive/MyDrive/mango'
img_size = (240, 320)

# Load the data
labels = os.listdir(os.path.join(data_dir, 'train'))
X_train, y_train = [], []
X_val, y_val = [], []
X_test, y_test = [], []
for label in labels:
    for img_name in os.listdir(os.path.join(data_dir, 'train', label)):
        img_path = os.path.join(data_dir, 'train', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_train.append(img_to_array(img))
        y_train.append(label)
    for img_name in os.listdir(os.path.join(data_dir, 'val', label)):
        img_path = os.path.join(data_dir, 'val', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_val.append(img_to_array(img))
        y_val.append(label)
    for img_name in os.listdir(os.path.join(data_dir, 'test', label)):
        img_path = os.path.join(data_dir, 'test', label, img_name)
        img = load_img(img_path, target_size=img_size)
        X_test.append(img_to_array(img))
        y_test.append(label)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)
X_test = np.array(X_test)
y_test = np.array(y_test)

# Preprocess the data
X_train = X_train.reshape(X_train.shape[0], -1) / 255.0
X_val = X_val.reshape(X_val.shape[0], -1) / 255.0
X_test = X_test.reshape(X_test.shape[0], -1) / 255.0

# Encode the labels
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

# Train a k-Nearest Neighbors classifier
clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train, y_train)

# Evaluate the classifier on the validation set
y_val_pred = clf.predict(X_val)
val_acc = accuracy_score(y_val, y_val_pred)
print(f'Validation accuracy: {val_acc:.3f}')

# Evaluate the classifier on the test set
y_test_pred = clf.predict(X_test)
test_acc = accuracy_score(y_test, y_test_pred)
print(f'Test accuracy: {test_acc:.3f}')

# %%
import matplotlib.pyplot as plt

# Define the data
models = ['KNN', 'SVM', 'Random Forest', 'Decision Tree']
val_accs = [0.642, 0.652, 0.913, 0.778]
test_accs = [0.630, 0.661, 0.907, 0.742]

# Define the parameters for the bar chart
x = list(range(len(models)))
width = 0.35

# Create the bar chart
fig, ax = plt.subplots()
rects1 = ax.bar([i - width/2 for i in x], val_accs, width, label='Validation Accuracy')
rects2 = ax.bar([i + width/2 for i in x], test_accs, width, label='Test Accuracy')

# Add labels, titles, and legends
ax.set_ylabel('Accuracy')
ax.set_title('Model Accuracy')
ax.set_xticks(x)
ax.set_xticklabels(models)
ax.legend()

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt

models = ['KNN', 'SVM', 'Random Forest', 'Decision Tree']
accuracies = [0.642, 0.652, 0.913, 0.778]

fig, ax = plt.subplots()
ax.pie(accuracies, labels=models, autopct='%1.1f%%')
ax.set_title('Accuracy Distribution Across Models')

plt.show()
